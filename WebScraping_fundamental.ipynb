# %% [markdown]
# <a href="https://colab.research.google.com/github/Satvik26/Amazon-Web-Scraping/blob/main/WebScraping_fundamental.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Beautiful is a python library which is used to parse the html code and find the elements inside it.
#
# **Installing beautifulSoup using the below command.**

# %%
pip install bs4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# **Installing request since we will be sending request from our local system the amazon website.**

# %%
pip install requests
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# **Installing pandas because after scraping data from online website we need to convert it to other formats such as csv.**

# %%
pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# **Import all the above packages.**

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %% [markdown]
# **Send request to amazon website**

# %%
url = "https://www.amazon.it/s?k=books&__mk_it_IT=%C3%85M%C3%85%C5%BD%C3%95%C3%91&crid=1UPARTD6PUDCH&sprefix=books%2Caps%2C90&ref=nb_sb_noss_1"

# %%
# Header for request
HEADERS = ({'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36','Accept-Language':'en-Us,en;q=0.5'})

# %%
webpage = requests.get(url , headers = HEADERS)

# %%
# At this step the request is returning the document in bytes format.
type(webpage.content)
# Out:
# bytes

# %%
# To change it to html document we need to parse it using beautifulSoup
soup = BeautifulSoup(webpage.content , 'html.parser')

# %%
# We get a BeautifulSoup object
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
# Fetch links as list of tag objects
links =  soup.find_all("a" , attrs = {'class':'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'})

# %%
links
# Out:
# [<a class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal" href="/grande-Gatsby-Ediz-integrale-Segnalibro/dp/8883377540/ref=sr_1_1?__mk_it_IT=%C3%85M%C3%85%C5%BD%C3%95%C3%91&amp;crid=1UPARTD6PUDCH&amp;keywords=books&amp;qid=1669675113&amp;qu=eyJxc2MiOiI1LjgwIiwicXNhIjoiNC45MyIsInFzcCI6IjMuMDQifQ%3D%3D&amp;sprefix=books%2Caps%2C90&amp;sr=8-1"><span class="a-size-base-plus a-color-base a-text-normal">Il grande Gatsby. Ediz. integrale. Con Segnalibro</span> </a>,
# ...

# %%
# Fetch the href link and then append the amazon website link to it to make a proper link
link =links[0].get("href")
product_list = "https://amazon.it/" + link

# %%
product_list
# Out:
# 'https://amazon.it//grande-Gatsby-Ediz-integrale-Segnalibro/dp/8883377540/ref=sr_1_1?__mk_it_IT=%C3%85M%C3%85%C5%BD%C3%95%C3%91&crid=1UPARTD6PUDCH&keywords=books&qid=1669675113&qu=eyJxc2MiOiI1LjgwIiwicXNhIjoiNC45MyIsInFzcCI6IjMuMDQifQ%3D%3D&sprefix=books%2Caps%2C90&sr=8-1'

# %% [markdown]
# **Now we need to again make the request to the new website page that we have stored in the product_list variable**

# %%
new_webpage = requests.get(product_list , headers = HEADERS)

# %%
new_soup = BeautifulSoup(new_webpage.content , 'html.parser')
type(new_soup)
# Out:
# bs4.BeautifulSoup

# %%
new_soup.prettify()
# Out:
# '<!DOCTYPE doctype html>\n<html class="a-no-js" data-19ax5a9jf="dingo" lang="it-it">\n <!-- sp:feature:head-start -->\n <head>\n  <script>\n   var aPageStart = (new Date()).getTime();\n  </script>\n  <meta charset="utf-8"/>\n  <!-- sp:end-feature:head-start -->\n  <!-- sp:feature:csm:head-open-part1 -->\n  <script type="text/javascript">\n   var ue_t0=ue_t0||+new Date();\n  </script>\n  <!-- sp:end-feature:csm:head-open-part1 -->\n  <!-- sp:feature:cs-optimization -->\n  <meta content="on" http-equiv="x-dns-prefetch-control"/>\n  <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>\n  <link href="https://m.media-amazon.com" rel="dns-prefetch"/>\n  <link href="https://completion.amazon.com" rel="dns-prefetch"/>\n  <!-- sp:end-feature:cs-optimization -->\n  <!-- sp:feature:csm:head-open-part2 -->\n  <script type="text/javascript">\n   window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;\nif (window.ue_ihb === 1) {\n\nvar ue_csm = window,\n    ue_hob = +new Da
# ...

# %%
new_soup.find("span", attrs= { 'id':'productTitle'}).text.strip()
# Out:
# 'Il grande Gatsby. Ediz. integrale. Con Segnalibro'

# %% [markdown]
# **Method # 1 (Recommended): The first one is BeautifulSoup's get_text method with strip argument as True So our code becomes:**
#
# clean_text = BeautifulSoup(raw_html, "lxml").get_text(strip=True)<br>
# print clean_text<br>
# Dear Parent,This is a test message,kindly ignore it.Thanks
#
# **Method # 2: The other option is to use python's library unicodedata**
#
# import unicodedata <br>
# text_string = BeautifulSoup(raw_html, "lxml").text<br>
# clean_text = unicodedata.normalize("NFKD",text_string) <br>
# print clean_text<br>
# Output: u'Dear Parent,This is a test message,kindly ignore it.Thanks'

# %%
# The symbols like euro where coming in a hexa decimal format hence unicofe
import unicodedata
clean_text = unicodedata.normalize("NFKD",new_soup.find('span', attrs= {'class':'a-size-base a-color-price'}).text.strip())
clean_text
# Out:
# '4,16 €'

# %%
# We can also do new_soup.find('',attrs = {'':''}).find('',attrs = {'':''}).text.strip()
new_soup.find('span', attrs = {'class':'a-icon-alt'}).text.strip()
# Out:
# '4,4 su 5 stelle'
